# %% [markdown]
# ### Calculating the training and validation set losses

# %%
import os
import urllib.request

file_path = "texts/J. K. Rowling - Harry Potter 1 - Sorcerer's Stone.txt"
url = "https://raw.githubusercontent.com/amephraim/nlp/blob/master/texts/J.%20K.%20Rowling%20-%20Harry%20Potter%201%20-%20Sorcerer's%20Stone.txt"

# Create the directory if it doesn't exist
os.makedirs(os.path.dirname(file_path), exist_ok=True)

if not os.path.exists(file_path):
    with urllib.request.urlopen(url) as response:
        text_data = response.read().decode('utf-8')
    with open(file_path, "w", encoding="utf-8") as file:
        file.write(text_data)
else:
    with open(file_path, "r", encoding="utf-8") as file:
        text_data = file.read()

# First 40 characters of the dataset
print(text_data[:39])
# Out:
# Harry Potter and the Sorcerer's Stone

# %% [markdown]
# ### Preprocessing steps:
#
# - Tokenize and get Token IDs
# - Create Input-Target pairs with DataLoader
# - Split Data into Train - Validation Set

# %%
# Tokenization
import tiktoken

tokenizer = tiktoken.get_encoding("gpt2")

total_characters = len(text_data)
total_tokens = len(tokenizer.encode(text_data))

print("Characters:", total_characters)
print("Tokens:", total_tokens)
# Out:
# Characters: 439742
# Tokens: 116725

# %%
# Implementing the DataLoader

from torch.utils.data import Dataset, DataLoader


class GPTDatasetV1(Dataset):
    def __init__(self, txt, tokenizer, max_length, stride):
        self.input_ids = []
        self.target_ids = []

        # Tokenize the entire text
        token_ids = tokenizer.encode(txt, allowed_special={"<|endoftext|>"})

        # Use a sliding window to chunk the book into overlapping sequences of max_length
        for i in range(0, len(token_ids) - max_length, stride):
            input_chunk = token_ids[i:i + max_length]
            target_chunk = token_ids[i + 1: i + max_length + 1]
            self.input_ids.append(torch.tensor(input_chunk))
            self.target_ids.append(torch.tensor(target_chunk))

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return self.input_ids[idx], self.target_ids[idx]


def create_dataloader_v1(txt, batch_size=4, max_length=256, 
                         stride=128, shuffle=True, drop_last=True,
                         num_workers=0):

    # Initialize the tokenizer
    tokenizer = tiktoken.get_encoding("gpt2")

    # Create dataset
    dataset = GPTDatasetV1(txt, tokenizer, max_length, stride)

    # Create dataloader
    dataloader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last=drop_last,
        num_workers=num_workers
    )

    return dataloader

# %%
GPT_CONFIG_124M = {
    "vocab_size": 50257,   # Vocabulary size
    "context_length": 256, # Shortened context length (orig: 1024)
    "emb_dim": 768,        # Embedding dimension
    "n_heads": 12,         # Number of attention heads
    "n_layers": 12,        # Number of layers
    "drop_rate": 0.1,      # Dropout rate
    "qkv_bias": False      # Query-key-value bias
}

# %%
import torch

# Train/validation ratio
train_ratio = 0.90
split_idx = int(train_ratio * len(text_data))
train_data = text_data[:split_idx]
val_data = text_data[split_idx:]


torch.manual_seed(123)

train_loader = create_dataloader_v1(
    train_data,
    batch_size=2,
    max_length=GPT_CONFIG_124M["context_length"],
    stride=GPT_CONFIG_124M["context_length"],
    drop_last=True,
    shuffle=True,
    num_workers=0
)

val_loader = create_dataloader_v1(
    val_data,
    batch_size=2,
    max_length=GPT_CONFIG_124M["context_length"],
    stride=GPT_CONFIG_124M["context_length"],
    drop_last=False,
    shuffle=False,
    num_workers=0
)

# %%
# Check the shapes of the batches

print("Train loader:")
for x, y in train_loader:
    print(x.shape, y.shape)

print("\nValidation loader:")
for x, y in val_loader:
    print(x.shape, y.shape)

print(f"Training Batches: {len(train_loader)}")
print(f"Validation Batches: {len(val_loader)}")
# Out:
# Train loader:
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
#
# Validation loader:
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([1, 256]) torch.Size([1, 256])
# Training Batches: 205
# Validation Batches: 23

# %% [markdown]
# ### Define the GPT Model we'll use

# %%
# Define the Layer Normalization and Feed Forward used in the Transformer block
import torch.nn as nn

class LayerNorm(nn.Module):
    def __init__(self, emb_dim):
        # Initialize the LayerNorm class with the embedding dimension and an epsilon value for numerical stability. The scale and shift parameters are learnable and initialized to ones and zeros, respectively.
        super().__init__()
        self.eps = 1e-5
        self.scale = nn.Parameter(torch.ones(emb_dim))
        self.shift = nn.Parameter(torch.zeros(emb_dim))

    def forward(self, x):
        # Compute the mean and variance of the input tensor x along the columns (dim=-1).
        mean = x.mean(dim=-1, keepdim=True)
        var = x.var(dim=-1, keepdim=True, unbiased=False)

        # Normalize the input tensor x using the computed mean and variance
        norm_x = (x - mean) / torch.sqrt(var + self.eps)
        
        # Apply the learnable scale and shift parameters to produce the final output.
        return self.scale * norm_x + self.shift

# GELU Activation Function 
class GELU(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, x):
        return 0.5 * x * (1 + torch.tanh(
            torch.sqrt(torch.tensor(2.0 / torch.pi)) * 
            (x + 0.044715 * torch.pow(x, 3))
        ))

class FeedForward(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        # nn.Sequential to create a neural network model
        self.layers = nn.Sequential(
            nn.Linear(cfg["emb_dim"], 4 * cfg["emb_dim"]), # Expnasion layer
            GELU(), # GELU activation
            nn.Linear(4 * cfg["emb_dim"], cfg["emb_dim"]), # Projection layer
        )

    def forward(self, x):
        return self.layers(x)

# %%
# Define the MultiHeadAttention used in the Transformer block
class MultiHeadAttention(nn.Module):
    def __init__(self, d_in, d_out, context_length, dropout, num_heads, qkv_bias=False):
        super().__init__()
        assert (d_out % num_heads == 0), \
            "d_out must be divisible by num_heads"

        self.d_out = d_out
        self.num_heads = num_heads
        self.head_dim = d_out // num_heads # Reduce the projection dim to match desired output dim

        self.W_query = nn.Linear(d_in, d_out, bias=qkv_bias)
        self.W_key = nn.Linear(d_in, d_out, bias=qkv_bias)
        self.W_value = nn.Linear(d_in, d_out, bias=qkv_bias)
        self.out_proj = nn.Linear(d_out, d_out)  # Linear layer to combine head outputs
        self.dropout = nn.Dropout(dropout)
        self.register_buffer(
            "mask",
            torch.triu(torch.ones(context_length, context_length),
                       diagonal=1)
        )

    def forward(self, x):
        b, num_tokens, d_in = x.shape

        keys = self.W_key(x) # Shape: (b, num_tokens, d_out)
        queries = self.W_query(x)
        values = self.W_value(x)

        # We implicitly split the matrix by adding a `num_heads` dimension
        # Unroll last dim: (b, num_tokens, d_out) -> (b, num_tokens, num_heads, head_dim)
        keys = keys.view(b, num_tokens, self.num_heads, self.head_dim) 
        values = values.view(b, num_tokens, self.num_heads, self.head_dim)
        queries = queries.view(b, num_tokens, self.num_heads, self.head_dim)

        # Transpose: (b, num_tokens, num_heads, head_dim) -> (b, num_heads, num_tokens, head_dim)
        keys = keys.transpose(1, 2)
        queries = queries.transpose(1, 2)
        values = values.transpose(1, 2)

        # Compute scaled dot-product attention (aka self-attention) with a causal mask
        attn_scores = queries @ keys.transpose(2, 3)  # Dot product for each head

        # Original mask truncated to the number of tokens and converted to boolean
        mask_bool = self.mask.bool()[:num_tokens, :num_tokens]

        # Use the mask to fill attention scores
        attn_scores.masked_fill_(mask_bool, -torch.inf)
        
        attn_weights = torch.softmax(attn_scores / keys.shape[-1]**0.5, dim=-1)
        attn_weights = self.dropout(attn_weights)

        # Shape: (b, num_tokens, num_heads, head_dim)
        context_vec = (attn_weights @ values).transpose(1, 2) 
        
        # Combine heads, where self.d_out = self.num_heads * self.head_dim
        context_vec = context_vec.contiguous().view(b, num_tokens, self.d_out) #tensor.view used to reshape the context vector to the desired output shape (b, num_tokens, d_out) by combining the outputs of all heads
        context_vec = self.out_proj(context_vec) # optional projection

        return context_vec

# %%
# Define the Transformer Block used in the GPT architecture.

class TransformerBlock(nn.Module):
    def __init__(self, cfg):
        # Initialize the TransformerBlock class with the given configuration. The block consists of a multi-head attention layer, a feedforward neural network, layer normalization, and dropout for regularization. The attention layer is configured based on the embedding dimension, context length, number of heads, dropout rate, and whether to use bias in the query-key-value projections.
        super().__init__()
        self.att = MultiHeadAttention(
            d_in=cfg["emb_dim"],
            d_out=cfg["emb_dim"],
            context_length=cfg["context_length"],
            num_heads=cfg["n_heads"], 
            dropout=cfg["drop_rate"],
            qkv_bias=cfg["qkv_bias"])
        self.ff = FeedForward(cfg)
        self.norm1 = LayerNorm(cfg["emb_dim"])
        self.norm2 = LayerNorm(cfg["emb_dim"])
        self.drop_shortcut = nn.Dropout(cfg["drop_rate"])

    def forward(self, x):
        # Shortcut connection for attention block
        shortcut = x
        x = self.norm1(x)
        x = self.att(x)  # Shape [batch_size, num_tokens, emb_size]
        x = self.drop_shortcut(x)
        x = x + shortcut  # Add the original input back

        # Shortcut connection for feed forward block
        shortcut = x
        x = self.norm2(x)
        x = self.ff(x)
        x = self.drop_shortcut(x)
        x = x + shortcut  # Add the original input back

        return x

# %%
# Define the GPTModel class
class GPTModel(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.tok_emb = nn.Embedding(cfg["vocab_size"], cfg["emb_dim"])
        self.pos_emb = nn.Embedding(cfg["context_length"], cfg["emb_dim"])
        self.drop_emb = nn.Dropout(cfg["drop_rate"])
        
        self.trf_blocks = nn.Sequential(
            *[TransformerBlock(cfg) for _ in range(cfg["n_layers"])])
        
        self.final_norm = LayerNorm(cfg["emb_dim"])
        self.out_head = nn.Linear(
            cfg["emb_dim"], cfg["vocab_size"], bias=False
        )

    def forward(self, in_idx):
        batch_size, seq_len = in_idx.shape
        tok_embeds = self.tok_emb(in_idx)
        pos_embeds = self.pos_emb(torch.arange(seq_len, device=in_idx.device))
        x = tok_embeds + pos_embeds  # Shape [batch_size, num_tokens, emb_size]
        x = self.drop_emb(x)
        x = self.trf_blocks(x)
        x = self.final_norm(x)
        logits = self.out_head(x)
        return logits

torch.manual_seed(123)
model = GPTModel(GPT_CONFIG_124M)
model.eval();  # Disable dropout during inference

# %% [markdown]
# ### Calculate the Training and Validation Loss

# %%
def calc_loss_batch(input_batch, target_batch, model, device):
    input_batch, target_batch = input_batch.to(device), target_batch.to(device)
    logits = model(input_batch)
    loss = torch.nn.functional.cross_entropy(logits.flatten(0, 1), target_batch.flatten())
    return loss


def calc_loss_loader(data_loader, model, device, num_batches=None):
    total_loss = 0.
    if len(data_loader) == 0:
        return float("nan")
    elif num_batches is None:
        num_batches = len(data_loader)
    else:
        # Reduce the number of batches to match the total number of batches in the data loader
        # if num_batches exceeds the number of batches in the data loader
        num_batches = min(num_batches, len(data_loader))
    for i, (input_batch, target_batch) in enumerate(data_loader):
        if i < num_batches:
            loss = calc_loss_batch(input_batch, target_batch, model, device)
            total_loss += loss.item()
        else:
            break
    return total_loss / num_batches

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Note:
# Uncommenting the following lines will allow the code to run on Apple Silicon chips, if applicable,
# which is approximately 2x faster than on an Apple CPU (as measured on an M3 MacBook Air).
# However, the resulting loss values may be slightly different.

#if torch.cuda.is_available():
#    device = torch.device("cuda")
#elif torch.backends.mps.is_available():
#    device = torch.device("mps")
#else:
#    device = torch.device("cpu")
#
# print(f"Using {device} device.")


model.to(device) # no assignment model = model.to(device) necessary for nn.Module classes


torch.manual_seed(123) # For reproducibility due to the shuffling in the data loader

with torch.no_grad(): # Disable gradient tracking for efficiency because we are not training, yet
    train_loss = calc_loss_loader(train_loader, model, device)
    val_loss = calc_loss_loader(val_loader, model, device)

print("Training loss:", train_loss)
print("Validation loss:", val_loss)
# Out:
# Training loss: 10.966670799255372
# Validation loss: 10.971507445625637

# %% [markdown]
# We got a big loss function because the model hasn't been trained yet. Nexr, we'll train the model to minimize the loss and get a better prediction.

# %% [markdown]
# ## TRAINING LOOP FOR THE LLM
# - Step 1: Initialize lists to track losses and tokens seen
#
# - Step 2: Start the main training loop
#
# - Step 3: Reset loss gradients from previous batch iteration
#
# - Step 4: Calculate loss gradients
#
# - Step 5: Update model weights using loss gradients
#
# - Step 6: Optional evaluation step
#
# - Step 7: Print a sample text after each epoch

# %%
# Define the evaluation function
def evaluate_model(model, train_loader, val_loader, device, eval_iter):
    model.eval()
    with torch.no_grad():
        train_loss = calc_loss_loader(train_loader, model, device, num_batches=eval_iter)
        val_loss = calc_loss_loader(val_loader, model, device, num_batches=eval_iter)
    model.train()
    return train_loss, val_loss

# %%
# Define the sample text function to track the training visually
def generate_and_print_sample(model, tokenizer, device, start_context):
    model.eval()
    context_size = model.pos_emb.weight.shape[0]
    encoded = text_to_token_ids(start_context, tokenizer).to(device)
    with torch.no_grad():
        token_ids = generate_text_simple(
            model=model, idx=encoded,
            max_new_tokens=50, context_size=context_size
        )
    decoded_text = token_ids_to_text(token_ids, tokenizer)
    print(decoded_text.replace("\n", " "))  # Compact print format
    model.train()

# %%
# Main Training Loop
def train_model_simple(model, train_loader, val_loader, optimizer, device, num_epochs,
                       eval_freq, eval_iter, start_context, tokenizer):
    # Initialize lists to track losses and tokens seen
    train_losses, val_losses, track_tokens_seen = [], [], []
    tokens_seen, global_step = 0, -1

    # Main training loop
    for epoch in range(num_epochs):
        model.train()  # Set model to training mode
        
        for input_batch, target_batch in train_loader:
            optimizer.zero_grad() # Reset loss gradients from previous batch iteration
            loss = calc_loss_batch(input_batch, target_batch, model, device)
            loss.backward() # Calculate loss gradients
            optimizer.step() # Update model weights using loss gradients
            tokens_seen += input_batch.numel() # Returns the total number of elements (or tokens) in the input_batch.
            global_step += 1

            # Optional evaluation step
            if global_step % eval_freq == 0: 
                train_loss, val_loss = evaluate_model(
                    model, train_loader, val_loader, device, eval_iter)
                train_losses.append(train_loss)
                val_losses.append(val_loss)
                track_tokens_seen.append(tokens_seen)
                print(f"Ep {epoch+1} (Step {global_step:06d}): "
                      f"Train loss {train_loss:.3f}, Val loss {val_loss:.3f}")

        # Print a sample text after each epoch
        generate_and_print_sample(
            model, tokenizer, device, start_context
        )

    return train_losses, val_losses, track_tokens_seen

# %%
# Start the training process
# Note:
# Uncomment the following code to calculate the execution time
import time
start_time = time.time()

torch.manual_seed(123)
model = GPTModel(GPT_CONFIG_124M)
model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=0.0004, weight_decay=0.1)

num_epochs = 10
train_losses, val_losses, tokens_seen = train_model_simple(
    model, train_loader, val_loader, optimizer, device,
    num_epochs=num_epochs, eval_freq=5, eval_iter=5,
    start_context="Every effort moves you", tokenizer=tokenizer
)

# Note:
# Uncomment the following code to show the execution time
end_time = time.time()
execution_time_minutes = (end_time - start_time) / 60
print(f"Training completed in {execution_time_minutes:.2f} minutes.")
# Out:
# Ep 1 (Step 000000): Train loss 9.666, Val loss 9.446
# Ep 1 (Step 000005): Train loss 8.265, Val loss 8.075
# Ep 1 (Step 000010): Train loss 7.347, Val loss 7.189
# Ep 1 (Step 000015): Train loss 6.784, Val loss 6.864
# Ep 1 (Step 000020): Train loss 6.527, Val loss 6.777
# Ep 1 (Step 000025): Train loss 6.954, Val loss 6.688
# Ep 1 (Step 000030): Train loss 6.794, Val loss 6.595
# Ep 1 (Step 000035): Train loss 6.683, Val loss 6.581
# Ep 1 (Step 000040): Train loss 6.410, Val loss 6.502
# Ep 1 (Step 000045): Train loss 6.336, Val loss 6.420
# Ep 1 (Step 000050): Train loss 6.631, Val loss 6.433
# Ep 1 (Step 000055): Train loss 6.498, Val loss 6.425
# Ep 1 (Step 000060): Train loss 6.405, Val loss 6.322
# Ep 1 (Step 000065): Train loss 6.325, Val loss 6.266
# Ep 1 (Step 000070): Train loss 5.953, Val loss 6.252
# Ep 1 (Step 000075): Train loss 6.072, Val loss 6.222
# Ep 1 (Step 000080): Train loss 6.215, Val loss 6.211
# Ep 1 (Step 000085): Train loss 6.134, Val loss 6.142
# Ep 1 (Step 000090): Train loss 6.042, Val loss 6.131
# Ep 1 (Step 000095): Train loss 5.888, Val loss 6.066
# Ep 1 (Step 000100): Train loss 5.981, Val loss 6.026
# Ep 1 (Step 000105): Train loss 5.843, Val loss 6.031
# Ep 1 (Step 000110): Train loss 5.899, Val loss 6.002
# Ep 1 (Step 000115): Train loss 5.859, Val loss 5.977
# Ep 1 (Step 000120): Train loss 5.592, Val loss 5.969
# Ep 1 (Step 000125): Train loss 5.685, Val loss 5.960
# Ep 1 (Step 000130): Train loss 5.400, Val loss 5.907
# Ep 1 (Step 000135): Train loss 5.474, Val loss 5.910
# Ep 1 (Step 000140): Train loss 5.780, Val loss 5.857
# Ep 1 (Step 000145): Train loss 5.653, Val loss 5.851
# Ep 1 (Step 000150): Train loss 5.563, Val loss 5.823
# Ep 1 (Step 000155): Train loss 5.796, Val loss 5.832
# Ep 1 (Step 000160): Train loss 5.323, Val loss 5.817
# Ep 1 (Step 000165): Train loss 5.513, Val loss 5.794
# Ep 1 (Step 000170): Train loss 5.528, Val loss 5.752
# Ep 1 (Step 000175): Train loss 5.594, Val loss 5.759
# Ep 1 (Step 000180): Train loss 5.344, Val loss 5.728
# Ep 1 (Step 000185): Train loss 5.349, Val loss 5.712
# Ep 1 (Step 000190): Train loss 5.437, Val loss 5.691
# Ep 1 (Step 000195): Train loss 5.388, Val loss 5.702
# Ep 1 (Step 000200): Train loss 5.224, Val loss 5.659
# Every effort moves you        "You've have been, and I'm  "I'm you have "I'mrid was a "I'm      "I'm
# Ep 2 (Step 000205): Train loss 5.376, Val loss 5.684
# Ep 2 (Step 000210): Train loss 5.507, Val loss 5.672
# Ep 2 (Step 000215): Train loss 4.966, Val loss 5.668
# Ep 2 (Step 000220): Train loss 5.413, Val loss 5.653
# Ep 2 (Step 000225): Train loss 5.193, Val loss 5.719
# Ep 2 (Step 000230): Train loss 5.270, Val loss 5.648
# Ep 2 (Step 000235): Train loss 5.151, Val loss 5.675
# Ep 2 (Step 000240): Train loss 5.519, Val loss 5.620
# Ep 2 (Step 000245): Train loss 5.072, Val loss 5.605
# Ep 2 (Step 000250): Train loss 5.248, Val loss 5.595
# Ep 2 (Step 000255): Train loss 5.159, Val loss 5.646
# Ep 2 (Step 000260): Train loss 5.196, Val loss 5.603
# Ep 2 (Step 000265): Train loss 4.922, Val loss 5.654
# Ep 2 (Step 000270): Train loss 5.203, Val loss 5.579
# Ep 2 (Step 000275): Train loss 5.149, Val loss 5.608
# Ep 2 (Step 000280): Train loss 5.027, Val loss 5.619
# Ep 2 (Step 000285): Train loss 5.207, Val loss 5.628
# Ep 2 (Step 000290): Train loss 5.275, Val loss 5.609
# Ep 2 (Step 000295): Train loss 4.844, Val loss 5.635
# Ep 2 (Step 000300): Train loss 5.143, Val loss 5.591
# Ep 2 (Step 000305): Train loss 4.996, Val loss 5.597
# Ep 2 (Step 000310): Train loss 4.840, Val loss 5.592
# Ep 2 (Step 000315): Train loss 5.256, Val loss 5.553
# Ep 2 (Step 000320): Train loss 5.240, Val loss 5.603
# Ep 2 (Step 000325): Train loss 5.000, Val loss 5.549
# Ep 2 (Step 000330): Train loss 5.237, Val loss 5.551
# Ep 2 (Step 000335): Train loss 5.079, Val loss 5.542
# Ep 2 (Step 000340): Train loss 5.030, Val loss 5.552
# Ep 2 (Step 000345): Train loss 4.865, Val loss 5.557
# Ep 2 (Step 000350): Train loss 4.865, Val loss 5.541
# Ep 2 (Step 000355): Train loss 5.347, Val loss 5.549
# Ep 2 (Step 000360): Train loss 4.860, Val loss 5.540
# Ep 2 (Step 000365): Train loss 5.380, Val loss 5.517
# Ep 2 (Step 000370): Train loss 5.263, Val loss 5.481
# Ep 2 (Step 000375): Train loss 4.913, Val loss 5.493
# Ep 2 (Step 000380): Train loss 5.044, Val loss 5.446
# Ep 2 (Step 000385): Train loss 5.042, Val loss 5.495
# Ep 2 (Step 000390): Train loss 4.829, Val loss 5.524
# Ep 2 (Step 000395): Train loss 4.921, Val loss 5.494
# Ep 2 (Step 000400): Train loss 4.793, Val loss 5.487
# Ep 2 (Step 000405): Train loss 4.984, Val loss 5.472
# Every effort moves you'll be
# Ep 3 (Step 000410): Train loss 4.764, Val loss 5.488
# Ep 3 (Step 000415): Train loss 4.895, Val loss 5.511
# Ep 3 (Step 000420): Train loss 4.685, Val loss 5.497
# Ep 3 (Step 000425): Train loss 4.871, Val loss 5.484
# Ep 3 (Step 000430): Train loss 4.775, Val loss 5.446
# Ep 3 (Step 000435): Train loss 4.629, Val loss 5.521
# Ep 3 (Step 000440): Train loss 4.630, Val loss 5.512
# Ep 3 (Step 000445): Train loss 4.896, Val loss 5.473
# Ep 3 (Step 000450): Train loss 4.855, Val loss 5.486
# Ep 3 (Step 000455): Train loss 4.748, Val loss 5.523
# Ep 3 (Step 000460): Train loss 4.754, Val loss 5.522
# Ep 3 (Step 000465): Train loss 4.597, Val loss 5.521
# Ep 3 (Step 000470): Train loss 4.550, Val loss 5.502
# Ep 3 (Step 000475): Train loss 4.822, Val loss 5.474
# Ep 3 (Step 000480): Train loss 4.697, Val loss 5.482
# Ep 3 (Step 000485): Train loss 4.748, Val loss 5.450
# Ep 3 (Step 000490): Train loss 4.589, Val loss 5.462
# Ep 3 (Step 000495): Train loss 4.739, Val loss 5.481
# Ep 3 (Step 000500): Train loss 4.534, Val loss 5.472
# Ep 3 (Step 000505): Train loss 4.332, Val loss 5.449
# Ep 3 (Step 000510): Train loss 4.599, Val loss 5.484
# Ep 3 (Step 000515): Train loss 4.685, Val loss 5.513
# Ep 3 (Step 000520): Train loss 4.600, Val loss 5.475
# Ep 3 (Step 000525): Train loss 4.668, Val loss 5.496
# Ep 3 (Step 000530): Train loss 4.491, Val loss 5.496
# Ep 3 (Step 000535): Train loss 4.607, Val loss 5.461
# Ep 3 (Step 000540): Train loss 4.541, Val loss 5.452
# Ep 3 (Step 000545): Train loss 4.384, Val loss 5.450
# Ep 3 (Step 000550): Train loss 4.511, Val loss 5.473
# Ep 3 (Step 000555): Train loss 4.571, Val loss 5.453
# Ep 3 (Step 000560): Train loss 4.555, Val loss 5.453
# Ep 3 (Step 000565): Train loss 4.347, Val loss 5.451
# Ep 3 (Step 000570): Train loss 4.465, Val loss 5.467
# Ep 3 (Step 000575): Train loss 4.341, Val loss 5.429
# Ep 3 (Step 000580): Train loss 4.361, Val loss 5.442
# Ep 3 (Step 000585): Train loss 4.288, Val loss 5.468
# Ep 3 (Step 000590): Train loss 4.291, Val loss 5.439
# Ep 3 (Step 000595): Train loss 4.496, Val loss 5.429
# Ep 3 (Step 000600): Train loss 4.515, Val loss 5.429
# Ep 3 (Step 000605): Train loss 4.353, Val loss 5.406
# Ep 3 (Step 000610): Train loss 4.286, Val loss 5.411
# Every effort moves you know what's
# Ep 4 (Step 000615): Train loss 4.393, Val loss 5.420
# Ep 4 (Step 000620): Train loss 4.377, Val loss 5.439
# Ep 4 (Step 000625): Train loss 4.415, Val loss 5.436
# Ep 4 (Step 000630): Train loss 4.182, Val loss 5.445
# Ep 4 (Step 000635): Train loss 4.314, Val loss 5.413
# Ep 4 (Step 000640): Train loss 4.264, Val loss 5.450
# Ep 4 (Step 000645): Train loss 4.238, Val loss 5.422
# Ep 4 (Step 000650): Train loss 4.092, Val loss 5.422
# Ep 4 (Step 000655): Train loss 4.560, Val loss 5.467
# Ep 4 (Step 000660): Train loss 4.259, Val loss 5.453
# Ep 4 (Step 000665): Train loss 4.047, Val loss 5.451
# Ep 4 (Step 000670): Train loss 4.294, Val loss 5.460
# Ep 4 (Step 000675): Train loss 4.157, Val loss 5.433
# Ep 4 (Step 000680): Train loss 4.207, Val loss 5.414
# Ep 4 (Step 000685): Train loss 4.217, Val loss 5.408
# Ep 4 (Step 000690): Train loss 4.208, Val loss 5.447
# Ep 4 (Step 000695): Train loss 3.982, Val loss 5.457
# Ep 4 (Step 000700): Train loss 4.232, Val loss 5.426
# Ep 4 (Step 000705): Train loss 4.163, Val loss 5.454
# Ep 4 (Step 000710): Train loss 3.880, Val loss 5.411
# Ep 4 (Step 000715): Train loss 4.195, Val loss 5.431
# Ep 4 (Step 000720): Train loss 3.830, Val loss 5.427
# Ep 4 (Step 000725): Train loss 4.067, Val loss 5.433
# Ep 4 (Step 000730): Train loss 4.374, Val loss 5.433
# Ep 4 (Step 000735): Train loss 4.525, Val loss 5.407
# Ep 4 (Step 000740): Train loss 4.117, Val loss 5.419
# Ep 4 (Step 000745): Train loss 3.989, Val loss 5.421
# Ep 4 (Step 000750): Train loss 4.080, Val loss 5.429
# Ep 4 (Step 000755): Train loss 4.034, Val loss 5.454
# Ep 4 (Step 000760): Train loss 4.142, Val loss 5.439
# Ep 4 (Step 000765): Train loss 4.176, Val loss 5.446
# Ep 4 (Step 000770): Train loss 3.922, Val loss 5.399
# Ep 4 (Step 000775): Train loss 4.178, Val loss 5.402
# Ep 4 (Step 000780): Train loss 3.972, Val loss 5.408
# Ep 4 (Step 000785): Train loss 4.053, Val loss 5.406
# Ep 4 (Step 000790): Train loss 3.943, Val loss 5.417
# Ep 4 (Step 000795): Train loss 3.963, Val loss 5.462
# Ep 4 (Step 000800): Train loss 4.012, Val loss 5.441
# Ep 4 (Step 000805): Train loss 4.049, Val loss 5.461
# Ep 4 (Step 000810): Train loss 3.757, Val loss 5.420
# Ep 4 (Step 000815): Train loss 3.785, Val loss 5.390
# Every effort moves you can't know, but I don't know what                                 "I don' you," said
# Ep 5 (Step 000820): Train loss 3.880, Val loss 5.381
# Ep 5 (Step 000825): Train loss 3.925, Val loss 5.407
# Ep 5 (Step 000830): Train loss 3.707, Val loss 5.432
# Ep 5 (Step 000835): Train loss 3.782, Val loss 5.428
# Ep 5 (Step 000840): Train loss 3.847, Val loss 5.429
# Ep 5 (Step 000845): Train loss 3.686, Val loss 5.472
# Ep 5 (Step 000850): Train loss 3.625, Val loss 5.465
# Ep 5 (Step 000855): Train loss 3.654, Val loss 5.475
# Ep 5 (Step 000860): Train loss 3.491, Val loss 5.474
# Ep 5 (Step 000865): Train loss 3.689, Val loss 5.491
# Ep 5 (Step 000870): Train loss 3.548, Val loss 5.509
# Ep 5 (Step 000875): Train loss 3.559, Val loss 5.484
# Ep 5 (Step 000880): Train loss 3.571, Val loss 5.502
# Ep 5 (Step 000885): Train loss 3.563, Val loss 5.501
# Ep 5 (Step 000890): Train loss 3.341, Val loss 5.502
# Ep 5 (Step 000895): Train loss 3.735, Val loss 5.487
# Ep 5 (Step 000900): Train loss 3.729, Val loss 5.511
# Ep 5 (Step 000905): Train loss 3.558, Val loss 5.506
# Ep 5 (Step 000910): Train loss 3.733, Val loss 5.477
# Ep 5 (Step 000915): Train loss 3.683, Val loss 5.477
# Ep 5 (Step 000920): Train loss 3.356, Val loss 5.500
# Ep 5 (Step 000925): Train loss 3.254, Val loss 5.505
# Ep 5 (Step 000930): Train loss 3.686, Val loss 5.521
# Ep 5 (Step 000935): Train loss 3.575, Val loss 5.510
# Ep 5 (Step 000940): Train loss 3.601, Val loss 5.483
# Ep 5 (Step 000945): Train loss 3.375, Val loss 5.489
# Ep 5 (Step 000950): Train loss 3.400, Val loss 5.449
# Ep 5 (Step 000955): Train loss 3.408, Val loss 5.490
# Ep 5 (Step 000960): Train loss 3.584, Val loss 5.520
# Ep 5 (Step 000965): Train loss 3.368, Val loss 5.498
# Ep 5 (Step 000970): Train loss 3.500, Val loss 5.507
# Ep 5 (Step 000975): Train loss 3.469, Val loss 5.502
# Ep 5 (Step 000980): Train loss 3.363, Val loss 5.483
# Ep 5 (Step 000985): Train loss 3.540, Val loss 5.472
# Ep 5 (Step 000990): Train loss 3.230, Val loss 5.482
# Ep 5 (Step 000995): Train loss 3.423, Val loss 5.487
# Ep 5 (Step 001000): Train loss 3.357, Val loss 5.494
# Ep 5 (Step 001005): Train loss 3.530, Val loss 5.528
# Ep 5 (Step 001010): Train loss 3.264, Val loss 5.488
# Ep 5 (Step 001015): Train loss 3.411, Val loss 5.477
# Ep 5 (Step 001020): Train loss 3.263, Val loss 5.486
# Every effort moves you can't know     "I'm not to you see you can you, I can you can you can you can -- I'm not to      "I'm not to get the " "I
# Ep 6 (Step 001025): Train loss 3.121, Val loss 5.488
# Ep 6 (Step 001030): Train loss 3.475, Val loss 5.513
# Ep 6 (Step 001035): Train loss 3.035, Val loss 5.520
# Ep 6 (Step 001040): Train loss 3.188, Val loss 5.548
# Ep 6 (Step 001045): Train loss 2.984, Val loss 5.541
# Ep 6 (Step 001050): Train loss 2.994, Val loss 5.530
# Ep 6 (Step 001055): Train loss 3.006, Val loss 5.561
# Ep 6 (Step 001060): Train loss 3.088, Val loss 5.597
# Ep 6 (Step 001065): Train loss 3.298, Val loss 5.596
# Ep 6 (Step 001070): Train loss 2.876, Val loss 5.593
# Ep 6 (Step 001075): Train loss 3.056, Val loss 5.569
# Ep 6 (Step 001080): Train loss 3.056, Val loss 5.588
# Ep 6 (Step 001085): Train loss 3.114, Val loss 5.565
# Ep 6 (Step 001090): Train loss 3.035, Val loss 5.571
# Ep 6 (Step 001095): Train loss 3.047, Val loss 5.580
# Ep 6 (Step 001100): Train loss 2.879, Val loss 5.606
# Ep 6 (Step 001105): Train loss 3.172, Val loss 5.630
# Ep 6 (Step 001110): Train loss 3.060, Val loss 5.653
# Ep 6 (Step 001115): Train loss 2.965, Val loss 5.645
# Ep 6 (Step 001120): Train loss 2.863, Val loss 5.639
# Ep 6 (Step 001125): Train loss 2.626, Val loss 5.625
# Ep 6 (Step 001130): Train loss 2.884, Val loss 5.626
# Ep 6 (Step 001135): Train loss 2.764, Val loss 5.611
# Ep 6 (Step 001140): Train loss 2.845, Val loss 5.631
# Ep 6 (Step 001145): Train loss 2.932, Val loss 5.637
# Ep 6 (Step 001150): Train loss 3.382, Val loss 5.668
# Ep 6 (Step 001155): Train loss 2.722, Val loss 5.669
# Ep 6 (Step 001160): Train loss 2.724, Val loss 5.656
# Ep 6 (Step 001165): Train loss 2.545, Val loss 5.631
# Ep 6 (Step 001170): Train loss 2.732, Val loss 5.629
# Ep 6 (Step 001175): Train loss 2.891, Val loss 5.601
# Ep 6 (Step 001180): Train loss 2.797, Val loss 5.650
# Ep 6 (Step 001185): Train loss 2.870, Val loss 5.650
# Ep 6 (Step 001190): Train loss 2.682, Val loss 5.651
# Ep 6 (Step 001195): Train loss 2.902, Val loss 5.647
# Ep 6 (Step 001200): Train loss 2.691, Val loss 5.656
# Ep 6 (Step 001205): Train loss 2.735, Val loss 5.659
# Ep 6 (Step 001210): Train loss 2.599, Val loss 5.663
# Ep 6 (Step 001215): Train loss 2.878, Val loss 5.639
# Ep 6 (Step 001220): Train loss 2.563, Val loss 5.609
# Ep 6 (Step 001225): Train loss 2.736, Val loss 5.626
# Every effort moves you nze!"   "I won! I said Harry, I can you, I'm not to go."     "You're not to you, I'm not going to you'll be  "I'm
# Ep 7 (Step 001230): Train loss 2.586, Val loss 5.632
# Ep 7 (Step 001235): Train loss 2.494, Val loss 5.641
# Ep 7 (Step 001240): Train loss 2.552, Val loss 5.653
# Ep 7 (Step 001245): Train loss 2.463, Val loss 5.688
# Ep 7 (Step 001250): Train loss 2.531, Val loss 5.725
# Ep 7 (Step 001255): Train loss 2.493, Val loss 5.745
# Ep 7 (Step 001260): Train loss 2.269, Val loss 5.717
# Ep 7 (Step 001265): Train loss 1.994, Val loss 5.752
# Ep 7 (Step 001270): Train loss 2.355, Val loss 5.790
# Ep 7 (Step 001275): Train loss 2.355, Val loss 5.794
# Ep 7 (Step 001280): Train loss 2.265, Val loss 5.823
# Ep 7 (Step 001285): Train loss 2.302, Val loss 5.829
# Ep 7 (Step 001290): Train loss 2.303, Val loss 5.868
# Ep 7 (Step 001295): Train loss 2.497, Val loss 5.870
# Ep 7 (Step 001300): Train loss 2.331, Val loss 5.847
# Ep 7 (Step 001305): Train loss 2.443, Val loss 5.831
# Ep 7 (Step 001310): Train loss 2.368, Val loss 5.823
# Ep 7 (Step 001315): Train loss 2.069, Val loss 5.778
# Ep 7 (Step 001320): Train loss 2.177, Val loss 5.820
# Ep 7 (Step 001325): Train loss 2.352, Val loss 5.837
# Ep 7 (Step 001330): Train loss 2.038, Val loss 5.862
# Ep 7 (Step 001335): Train loss 2.096, Val loss 5.837
# Ep 7 (Step 001340): Train loss 2.447, Val loss 5.846
# Ep 7 (Step 001345): Train loss 2.265, Val loss 5.833
# Ep 7 (Step 001350): Train loss 2.257, Val loss 5.885
# Ep 7 (Step 001355): Train loss 2.259, Val loss 5.844
# Ep 7 (Step 001360): Train loss 2.074, Val loss 5.801
# Ep 7 (Step 001365): Train loss 2.294, Val loss 5.794
# Ep 7 (Step 001370): Train loss 2.254, Val loss 5.838
# Ep 7 (Step 001375): Train loss 2.049, Val loss 5.868
# Ep 7 (Step 001380): Train loss 2.197, Val loss 5.877
# Ep 7 (Step 001385): Train loss 1.961, Val loss 5.895
# Ep 7 (Step 001390): Train loss 2.253, Val loss 5.894
# Ep 7 (Step 001395): Train loss 1.873, Val loss 5.881
# Ep 7 (Step 001400): Train loss 1.763, Val loss 5.876
# Ep 7 (Step 001405): Train loss 2.032, Val loss 5.906
# Ep 7 (Step 001410): Train loss 2.248, Val loss 5.922
# Ep 7 (Step 001415): Train loss 1.915, Val loss 5.912
# Ep 7 (Step 001420): Train loss 1.985, Val loss 5.894
# Ep 7 (Step 001425): Train loss 1.972, Val loss 5.872
# Ep 7 (Step 001430): Train loss 2.075, Val loss 5.873
# Every effort moves you'll bully house.  "I'm not a goodimey, I was still and you a  "You can't want to be in the  "I'm not to go back on the  "You can't have
# Ep 8 (Step 001435): Train loss 1.910, Val loss 5.883
# Ep 8 (Step 001440): Train loss 1.768, Val loss 5.907
# Ep 8 (Step 001445): Train loss 1.619, Val loss 5.944
# Ep 8 (Step 001450): Train loss 1.640, Val loss 6.001
# Ep 8 (Step 001455): Train loss 1.758, Val loss 5.990
# Ep 8 (Step 001460): Train loss 1.944, Val loss 6.010
# Ep 8 (Step 001465): Train loss 1.619, Val loss 6.038
# Ep 8 (Step 001470): Train loss 1.585, Val loss 6.066
# Ep 8 (Step 001475): Train loss 1.747, Val loss 6.083
# Ep 8 (Step 001480): Train loss 1.376, Val loss 6.061
# Ep 8 (Step 001485): Train loss 1.654, Val loss 6.107
# Ep 8 (Step 001490): Train loss 1.658, Val loss 6.101
# Ep 8 (Step 001495): Train loss 1.441, Val loss 6.063
# Ep 8 (Step 001500): Train loss 1.654, Val loss 6.071
# Ep 8 (Step 001505): Train loss 1.560, Val loss 6.068
# Ep 8 (Step 001510): Train loss 1.414, Val loss 6.055
# Ep 8 (Step 001515): Train loss 1.761, Val loss 6.078
# Ep 8 (Step 001520): Train loss 1.640, Val loss 6.142
# Ep 8 (Step 001525): Train loss 1.292, Val loss 6.144
# Ep 8 (Step 001530): Train loss 1.587, Val loss 6.135
# Ep 8 (Step 001535): Train loss 1.571, Val loss 6.139
# Ep 8 (Step 001540): Train loss 1.685, Val loss 6.093
# Ep 8 (Step 001545): Train loss 1.648, Val loss 6.111
# Ep 8 (Step 001550): Train loss 1.604, Val loss 6.122
# Ep 8 (Step 001555): Train loss 1.474, Val loss 6.177
# Ep 8 (Step 001560): Train loss 1.223, Val loss 6.147
# Ep 8 (Step 001565): Train loss 1.205, Val loss 6.122
# Ep 8 (Step 001570): Train loss 1.361, Val loss 6.132
# Ep 8 (Step 001575): Train loss 1.341, Val loss 6.129
# Ep 8 (Step 001580): Train loss 1.302, Val loss 6.126
# Ep 8 (Step 001585): Train loss 1.238, Val loss 6.196
# Ep 8 (Step 001590): Train loss 1.532, Val loss 6.189
# Ep 8 (Step 001595): Train loss 1.182, Val loss 6.192
# Ep 8 (Step 001600): Train loss 1.371, Val loss 6.204
# Ep 8 (Step 001605): Train loss 1.228, Val loss 6.176
# Ep 8 (Step 001610): Train loss 1.127, Val loss 6.209
# Ep 8 (Step 001615): Train loss 1.258, Val loss 6.243
# Ep 8 (Step 001620): Train loss 1.270, Val loss 6.205
# Ep 8 (Step 001625): Train loss 1.565, Val loss 6.178
# Ep 8 (Step 001630): Train loss 1.127, Val loss 6.183
# Ep 8 (Step 001635): Train loss 1.309, Val loss 6.200
# Every effort moves you know  "I want to you," said Dumbledore, I'm not," said Hermione, "you know what you "But?" said Dumbledore, "We've got the  "What is?" " " " "
# Ep 9 (Step 001640): Train loss 1.193, Val loss 6.213
# Ep 9 (Step 001645): Train loss 1.213, Val loss 6.298
# Ep 9 (Step 001650): Train loss 1.122, Val loss 6.320
# Ep 9 (Step 001655): Train loss 1.039, Val loss 6.294
# Ep 9 (Step 001660): Train loss 1.058, Val loss 6.301
# Ep 9 (Step 001665): Train loss 1.186, Val loss 6.320
# Ep 9 (Step 001670): Train loss 1.138, Val loss 6.362
# Ep 9 (Step 001675): Train loss 0.918, Val loss 6.374
# Ep 9 (Step 001680): Train loss 1.227, Val loss 6.372
# Ep 9 (Step 001685): Train loss 1.077, Val loss 6.419
# Ep 9 (Step 001690): Train loss 1.121, Val loss 6.432
# Ep 9 (Step 001695): Train loss 0.942, Val loss 6.392
# Ep 9 (Step 001700): Train loss 1.130, Val loss 6.378
# Ep 9 (Step 001705): Train loss 0.928, Val loss 6.393
# Ep 9 (Step 001710): Train loss 0.908, Val loss 6.432
# Ep 9 (Step 001715): Train loss 0.827, Val loss 6.453
# Ep 9 (Step 001720): Train loss 0.930, Val loss 6.429
# Ep 9 (Step 001725): Train loss 1.121, Val loss 6.436
# Ep 9 (Step 001730): Train loss 0.665, Val loss 6.456
# Ep 9 (Step 001735): Train loss 1.130, Val loss 6.467
# Ep 9 (Step 001740): Train loss 0.937, Val loss 6.430
# Ep 9 (Step 001745): Train loss 0.889, Val loss 6.495
# Ep 9 (Step 001750): Train loss 0.727, Val loss 6.534
# Ep 9 (Step 001755): Train loss 0.915, Val loss 6.493
# Ep 9 (Step 001760): Train loss 1.015, Val loss 6.438
# Ep 9 (Step 001765): Train loss 0.967, Val loss 6.477
# Ep 9 (Step 001770): Train loss 0.824, Val loss 6.492
# Ep 9 (Step 001775): Train loss 1.042, Val loss 6.491
# Ep 9 (Step 001780): Train loss 1.014, Val loss 6.498
# Ep 9 (Step 001785): Train loss 1.073, Val loss 6.491
# Ep 9 (Step 001790): Train loss 0.929, Val loss 6.522
# Ep 9 (Step 001795): Train loss 0.772, Val loss 6.509
# Ep 9 (Step 001800): Train loss 0.777, Val loss 6.512
# Ep 9 (Step 001805): Train loss 0.858, Val loss 6.526
# Ep 9 (Step 001810): Train loss 0.843, Val loss 6.537
# Ep 9 (Step 001815): Train loss 0.835, Val loss 6.553
# Ep 9 (Step 001820): Train loss 0.832, Val loss 6.519
# Ep 9 (Step 001825): Train loss 0.767, Val loss 6.552
# Ep 9 (Step 001830): Train loss 0.619, Val loss 6.546
# Ep 9 (Step 001835): Train loss 0.825, Val loss 6.548
# Ep 9 (Step 001840): Train loss 0.654, Val loss 6.562
# Every effort moves you look to. I can't see you the mirror?"  "Why me?" said Harry.  "Oh, I'm head," said Harry. "Back, I "Oh, you, I'll be in this stuff
# Ep 10 (Step 001845): Train loss 0.686, Val loss 6.591
# Ep 10 (Step 001850): Train loss 0.674, Val loss 6.637
# Ep 10 (Step 001855): Train loss 0.682, Val loss 6.648
# Ep 10 (Step 001860): Train loss 0.546, Val loss 6.670
# Ep 10 (Step 001865): Train loss 0.725, Val loss 6.689
# Ep 10 (Step 001870): Train loss 0.571, Val loss 6.663
# Ep 10 (Step 001875): Train loss 0.630, Val loss 6.692
# Ep 10 (Step 001880): Train loss 0.612, Val loss 6.748
# Ep 10 (Step 001885): Train loss 0.676, Val loss 6.752
# Ep 10 (Step 001890): Train loss 0.648, Val loss 6.739
# Ep 10 (Step 001895): Train loss 0.643, Val loss 6.726
# Ep 10 (Step 001900): Train loss 0.437, Val loss 6.722
# Ep 10 (Step 001905): Train loss 0.527, Val loss 6.740
# Ep 10 (Step 001910): Train loss 0.552, Val loss 6.707
# Ep 10 (Step 001915): Train loss 0.498, Val loss 6.754
# Ep 10 (Step 001920): Train loss 0.629, Val loss 6.735
# Ep 10 (Step 001925): Train loss 0.533, Val loss 6.733
# Ep 10 (Step 001930): Train loss 0.595, Val loss 6.750
# Ep 10 (Step 001935): Train loss 0.491, Val loss 6.798
# Ep 10 (Step 001940): Train loss 0.610, Val loss 6.807
# Ep 10 (Step 001945): Train loss 0.516, Val loss 6.788
# Ep 10 (Step 001950): Train loss 0.569, Val loss 6.821
# Ep 10 (Step 001955): Train loss 0.295, Val loss 6.800
# Ep 10 (Step 001960): Train loss 0.436, Val loss 6.774
# Ep 10 (Step 001965): Train loss 0.439, Val loss 6.796
# Ep 10 (Step 001970): Train loss 0.309, Val loss 6.852
# Ep 10 (Step 001975): Train loss 0.524, Val loss 6.845
# Ep 10 (Step 001980): Train loss 0.617, Val loss 6.874
# Ep 10 (Step 001985): Train loss 0.439, Val loss 6.911
# Ep 10 (Step 001990): Train loss 0.468, Val loss 6.862
# Ep 10 (Step 001995): Train loss 0.497, Val loss 6.819
# Ep 10 (Step 002000): Train loss 0.491, Val loss 6.828
# Ep 10 (Step 002005): Train loss 0.437, Val loss 6.849
# Ep 10 (Step 002010): Train loss 0.483, Val loss 6.885
# Ep 10 (Step 002015): Train loss 0.404, Val loss 6.853
# Ep 10 (Step 002020): Train loss 0.439, Val loss 6.857
# Ep 10 (Step 002025): Train loss 0.472, Val loss 6.866
# Ep 10 (Step 002030): Train loss 0.457, Val loss 6.834
# Ep 10 (Step 002035): Train loss 0.492, Val loss 6.820
# Ep 10 (Step 002040): Train loss 0.326, Val loss 6.822
# Ep 10 (Step 002045): Train loss 0.391, Val loss 6.829
# Every effort moves you."  "Not fast enough," said Hagrid. "It's not easy ter catch a unicorn, they're powerful magic creatures. "An' a tree?"  "Give it's not easy when I'm not say?"
# Training completed in 419.98 minutes.

# %% [markdown]
# We can see the validation loss is much larger than the training loss. It's a clear sign that the model overfit to the training set.

# %% [markdown]
# ## DECODING STRATEGIES TO CONTROL RANDOMNESS

# %%
def generate_text_simple(model, idx, max_new_tokens, context_size):
    # idx is (batch, n_tokens) array of indices in the current context
    for _ in range(max_new_tokens):
        
        # Crop current context if it exceeds the supported context size
        # E.g., if LLM supports only 5 tokens, and the context size is 10
        # then only the last 5 tokens are used as context
        idx_cond = idx[:, -context_size:]
        
        # Get the predictions
        with torch.no_grad():
            logits = model(idx_cond)
        
        # Focus only on the last time step
        # (batch, n_tokens, vocab_size) becomes (batch, vocab_size)
        logits = logits[:, -1, :]  

        # Apply softmax to get probabilities
        probas = torch.softmax(logits, dim=-1)  # (batch, vocab_size)

        # Get the idx of the vocab entry with the highest probability value
        idx_next = torch.argmax(probas, dim=-1, keepdim=True)  # (batch, 1)

        # Append sampled index to the running sequence
        idx = torch.cat((idx, idx_next), dim=1)  # (batch, n_tokens+1)

    return idx

# %%
tokenizer = tiktoken.get_encoding("gpt2")
def text_to_token_ids(text, tokenizer):
    encoded = tokenizer.encode(text, allowed_special={'<|endoftext|>'})
    encoded_tensor = torch.tensor(encoded).unsqueeze(0) # add batch dimension
    return encoded_tensor

def token_ids_to_text(token_ids, tokenizer):
    flat = token_ids.squeeze(0) # remove batch dimension
    return tokenizer.decode(flat.tolist())

token_ids = generate_text_simple(
    model=model,
    idx=text_to_token_ids("Every effort moves you", tokenizer),
    max_new_tokens=25,
    context_size=GPT_CONFIG_124M["context_length"]
)

print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# Output text:
#  Every effort moves you."
#
# "It's lucky it's dark. I haven't blushed so much since Madam Pomfrey
# told

# %% [markdown]
# ### DECODING STRATEGY 1: TEMPERATURE SCALING

# %%
vocab = { 
    "closer": 0,
    "every": 1, 
    "effort": 2, 
    "forward": 3,
    "inches": 4,
    "moves": 5, 
    "pizza": 6,
    "toward": 7,
    "you": 8,
} 

inverse_vocab = {v: k for k, v in vocab.items()}

# %%
next_token_logits = torch.tensor(
[4.51, 0.89, -1.90, 6.75, 1.63, -1.62, -1.89, 6.28, 1.79]
)

# %%
probas = torch.softmax(next_token_logits, dim=0)
next_token_id = torch.argmax(probas).item()
print(inverse_vocab[next_token_id])
# Out:
# forward

# %%
torch.manual_seed(123)
next_token_id = torch.multinomial(probas, num_samples=1).item()
print(inverse_vocab[next_token_id])
# Out:
# forward

# %%
def print_sampled_tokens(probas):
    torch.manual_seed(123) # Manual seed for reproducibility
    sample = [torch.multinomial(probas, num_samples=1).item() for i in range(1_000)]
    sampled_ids = torch.bincount(torch.tensor(sample))
    for i, freq in enumerate(sampled_ids):
        print(f"{freq} x {inverse_vocab[i]}")

print_sampled_tokens(probas)
# Out:
# 73 x closer
# 0 x every
# 0 x effort
# 582 x forward
# 2 x inches
# 0 x moves
# 0 x pizza
# 343 x toward

# %%
def softmax_with_temperature(logits, temperature):
    scaled_logits = logits / temperature
    return torch.softmax(scaled_logits, dim=0)

# Temperature values
temperatures = [1, 0.1, 5]  # Original, higher confidence, and lower confidence

# Calculate scaled probabilities
scaled_probas = [softmax_with_temperature(next_token_logits, T) for T in temperatures]

# %%
# Plotting
import matplotlib.pyplot as plt
x = torch.arange(len(vocab))
bar_width = 0.15

fig, ax = plt.subplots(figsize=(5, 3))
for i, T in enumerate(temperatures):
    rects = ax.bar(x + i * bar_width, scaled_probas[i], bar_width, label=f'Temperature = {T}')

ax.set_ylabel('Probability')
ax.set_xticks(x)
ax.set_xticklabels(vocab.keys(), rotation=90)
ax.legend()

plt.tight_layout()
plt.savefig("temperature-plot.pdf")
plt.show()

# %% [markdown]
# ### DECODING STRATEGY 2: Top-k sampling

# %%
top_k = 3
top_logits, top_pos = torch.topk(next_token_logits, top_k)
print("Top logits:", top_logits)
print("Top positions:", top_pos)
# Out:
# Top logits: tensor([6.7500, 6.2800, 4.5100])
# Top positions: tensor([3, 7, 0])

# %%
new_logits = torch.where(
    condition=next_token_logits < top_logits[-1],
    input=torch.tensor(float("-inf")), 
    other=next_token_logits
)

print(new_logits)
# Out:
# tensor([4.5100,   -inf,   -inf, 6.7500,   -inf,   -inf,   -inf, 6.2800,   -inf])

# %%
topk_probas = torch.softmax(new_logits, dim=0)
print(topk_probas)
# Out:
# tensor([0.0615, 0.0000, 0.0000, 0.5775, 0.0000, 0.0000, 0.0000, 0.3610, 0.0000])

# %% [markdown]
# ### Merge Temperature Scaling and Top-k sampling
#
# - Step 1: For-loop is the same as before: Get logits, and only focus on last time step
#
# - Step 2: In this new section, we filter logits with top_k sampling
#
# - Step 3: This is the new section where we apply temperature scaling
#
# - Step 4: Carry out greedy next-token selection as before when temperature scaling is disabled
#
# - Step 5: Stop generating early if end-of-sequence token is encountered and eos_id is specified

# %%
def generate(model, idx, max_new_tokens, context_size, temperature=0.0, top_k=None, eos_id=None):

    # For-loop is the same as before: Get logits, and only focus on last time step
    for _ in range(max_new_tokens):
        idx_cond = idx[:, -context_size:]
        with torch.no_grad():
            logits = model(idx_cond)
        logits = logits[:, -1, :]

        # New: Filter logits with top_k sampling
        if top_k is not None:
            # Keep only top_k values
            top_logits, _ = torch.topk(logits, top_k)
            min_val = top_logits[:, -1]
            logits = torch.where(logits < min_val, torch.tensor(float("-inf")).to(logits.device), logits)

        # New: Apply temperature scaling
        if temperature > 0.0:
            logits = logits / temperature

            # Apply softmax to get probabilities
            probs = torch.softmax(logits, dim=-1)  # (batch_size, context_len)

            # Sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1)  # (batch_size, 1)

        # Otherwise same as before: get idx of the vocab entry with the highest logits value
        else:
            idx_next = torch.argmax(logits, dim=-1, keepdim=True)  # (batch_size, 1)

        if idx_next == eos_id:  # Stop generating early if end-of-sequence token is encountered and eos_id is specified
            break

        # Same as before: append sampled index to the running sequence
        idx = torch.cat((idx, idx_next), dim=1)  # (batch_size, num_tokens+1)

    return idx

# %%
torch.manual_seed(123)

token_ids = generate(
    model=model,
    idx=text_to_token_ids("Every effort moves you", tokenizer),
    max_new_tokens=15,
    context_size=GPT_CONFIG_124M["context_length"],
    top_k=25,
    temperature=1.4
)

print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# Output text:
#  Every effort moves you."
#
# "Chuck you think I'm wearing Ag back, but she
